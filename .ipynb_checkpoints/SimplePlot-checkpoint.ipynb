# %%
import random
import matplotlib.pyplot as plt

# %%
def create_data(size):
    # Create a list of 10 random numbers
    numbers=[]
    for i in range(size):
        numbers.append(random.random())
    return numbers

# %%
numbers = create_data(20)
# Plot them
plt.plot(numbers)
plt.show()
